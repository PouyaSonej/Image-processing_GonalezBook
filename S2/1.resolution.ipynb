# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1.Resolution

# %%
#Original image
img1 = cv2.imread('/content/Fig2.19(a).jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img1,cmap='gray')
img1.shape
# Out:
# (1024, 1024)

# %%
#changing Resolution

i , j = 256 , 256
img11 = cv2.resize(img1,(i,j), interpolation = cv2.INTER_AREA)
plt.imshow(img11,cmap='gray')
img11.shape
# Out:
# (256, 256)
