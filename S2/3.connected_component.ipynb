# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def connected_components(filename, sigma=1.0, t=0.5, connectivity=2):
    # convert the image to grayscale
    # gray_image = skimage.color.rgb2gray(filename)
    gray_image = filename
    # denoise the image with a Gaussian filter
    blurred_image = skimage.filters.gaussian(gray_image, sigma=sigma)
    # mask the image according to threshold
    binary_mask = blurred_image < t
    # perform connected component analysis
    labeled_image, count = skimage.measure.label(binary_mask,
                                                 connectivity=connectivity, return_num=True)
    return labeled_image, count

# %%
#Original image Downloaded from internet
img3 = cv2.imread("/content/images.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img3,cmap='gray')
img3.shape
# Out:
# (214, 235)

# %%
x , y = connected_components(img3)
plt.imshow(x,cmap='gray')
y
# Out:
# 5
