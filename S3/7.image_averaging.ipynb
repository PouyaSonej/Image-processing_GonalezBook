# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
Img1 = []
row,col= img1.shape
mean = 0
var = 0.1
sigma = var**0.5
Img = img1
for i in range(20):
      gauss = np.random.normal(mean,sigma,(row,col))
      gauss = gauss.reshape(row,col)
      Img1.append( Img + gauss )

for i in range(20):
    plt.subplot(4, 5, i + 1)
    # Convert [0 - 255] to [0.0 - 1.0]
    # out[i] = cv2.normalize(img22[i].astype('float'), None, 0.0, 1.0, cv2.NORM_MINMAX)
    plt.imshow(np.array(Img1[i]),cmap='gray')
plt.show()

# plt.imshow(Img1,cmap='gray')

# %%
x = 0
for i in range(20):
  z = x + Img[i]
  x = Img1[i]
plt.imshow(z/20,cmap='gray')
plt.axis("off")
# Out:
# (-0.5, 682.5, 999.5, -0.5)
