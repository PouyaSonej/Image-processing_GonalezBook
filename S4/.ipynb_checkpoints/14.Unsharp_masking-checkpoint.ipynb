# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img9 = plt.imread("/content/fig4.28(a).jpg")
plt.imshow(img9,cmap='gray')
plt.axis("off")
img7.shape
# Out:
# (444, 508)

# %% [markdown]
# ### Unsharp masking

# %%
# Blur the image
gauss = cv2.GaussianBlur(img9, (3,3), 0)
# Apply Unsharp masking
unsharp_image = cv2.addWeighted(img9, 2, gauss, -1, 0)
plt.imshow(unsharp_image,cmap='gray')
